# %%
import pandas as pd
df =pd.read_excel('dataset/SaleData.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       43 non-null     float64
#  6   Unit_price  43 non-null     float64
#  7   Sale_amt    43 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.0+ KB

# %%
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6  2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.0      1198.0
# ...

# %%
df1 =df.groupby(df['Region']).sum()['Sale_amt']
df1
# Out:
# C:\Users\BLDEA12\AppData\Local\Temp\ipykernel_1404\1703004117.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 =df.groupby(df['Region']).sum()['Sale_amt']
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %%
import matplotlib.pyplot as plt
df1=df.groupby(df['Region']).sum()['Sale_amt']
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('sales amount as region', fontsize=15) 
ax.set_xlabel('Region',fontsize=15)
ax.set_ylabel('sales amount',fontsize=15)
ax.bar(df1.index,df1)
# Out:
# C:\Users\BLDEA12\AppData\Local\Temp\ipykernel_1404\2677445255.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1=df.groupby(df['Region']).sum()['Sale_amt']
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
df2=df.groupby(df['Item']).sum()['Units']
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('total units tally', fontsize=15) 
ax.set_xlabel('Items',fontsize=15)
ax.set_ylabel('Unitet',fontsize=15)
ax.bar(df2.index,df2)
# Out:
# C:\Users\BLDEA12\AppData\Local\Temp\ipykernel_1404\2442743386.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2=df.groupby(df['Item']).sum()['Units']
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
df3=df.groupby(df['Manager']).sum()['Sale_amt']
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('total sales by manager', fontsize=15) 
ax.set_xlabel('Manager',fontsize=15)
ax.set_ylabel('sales amount',fontsize=15)
ax.bar(df3.index,df3)
# Out:
# C:\Users\BLDEA12\AppData\Local\Temp\ipykernel_1404\313217290.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3=df.groupby(df['Manager']).sum()['Sale_amt']
# <BarContainer object of 4 artists>
